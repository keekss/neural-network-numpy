# %%
# %reload_ext autoreload
# %autoreload 2

import logging
import scripts.logging_config as _

def foo(x):
    logging.info("Running %d", x)

foo(2)
foo(3)
# Out:
# foo(), line 8 (2024-02-12 @ 01:12:16)
# -> [INFO] Running 2
#
# foo(), line 8 (2024-02-12 @ 01:12:16)
# -> [INFO] Running 3

# %%
import scripts.load_sample_data as load_sample_data

load_sample_data.prepare_and_load_fashion_mnist_data()

1
# Out:
# download_and_save_files(), line 24 (2024-02-12 @ 01:12:16)
# -> [INFO] File train-images-idx3-ubyte.gz already exists in ./data/
#
# download_and_save_files(), line 24 (2024-02-12 @ 01:12:16)
# -> [INFO] File train-labels-idx1-ubyte.gz already exists in ./data/
#
# download_and_save_files(), line 24 (2024-02-12 @ 01:12:16)
# -> [INFO] File t10k-images-idx3-ubyte.gz already exists in ./data/
#
# download_and_save_files(), line 24 (2024-02-12 @ 01:12:16)
# -> [INFO] File t10k-labels-idx1-ubyte.gz already exists in ./data/
# 1
